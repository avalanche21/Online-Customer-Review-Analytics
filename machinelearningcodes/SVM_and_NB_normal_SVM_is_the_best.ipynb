# %% [markdown]
# #Reference
# # https://towardsdatascience.com/multi-class-text-classification-with-scikit-learn-12f1e60e0a9f

# %%
import pandas as pd
df = pd.read_csv('consumer_complaints_small.csv')
df.head()
# Out:
#            product                       consumer_complaint_narrative
# 0  Debt collection  XXXX has claimed I owe them {$27.00} for XXXX ...
# 1    Consumer Loan  Due to inconsistencies in the amount owed that...
# 2         Mortgage  In XX/XX/XXXX my wages that I earned at my job...
# 3         Mortgage  I have an open and current mortgage with Chase...
# 4         Mortgage  XXXX was submitted XX/XX/XXXX. At the time I s...

# %%
from io import StringIO
col = ['product', 'consumer_complaint_narrative']
df = df[col]
df = df[pd.notnull(df['consumer_complaint_narrative'])]
df.columns = ['product', 'consumer_complaint_narrative']
df['category_id'] = df['product'].factorize()[0]
category_id_df = df[['product', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'product']].values)
df.head()
# Out:
#            product                       consumer_complaint_narrative  \
# 0  Debt collection  XXXX has claimed I owe them {$27.00} for XXXX ...
# 1    Consumer Loan  Due to inconsistencies in the amount owed that...
# 2         Mortgage  In XX/XX/XXXX my wages that I earned at my job...
# 3         Mortgage  I have an open and current mortgage with Chase...
# 4         Mortgage  XXXX was submitted XX/XX/XXXX. At the time I s...
#
#    category_id
# 0            0
# 1            1
# 2            2
# 3            2
# 4            2

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))

df.groupby('product').consumer_complaint_narrative.count().plot.bar(ylim=0)
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
#features = tfidf.fit_transform(df.consumer_complaint_narrative).toarray()

features = tfidf.fit_transform(df.consumer_complaint_narrative)

labels = df.category_id
features.shape
# Out:
# (66806, 159200)

# %%
#We can use sklearn.feature_selection.chi2 to find the terms that are the most correlated with each of the products:

# %%
# from sklearn.feature_selection import chi2
# import numpy as np
# N = 2
# for Product, category_id in sorted(category_to_id.items()):
#   features_chi2 = chi2(features, labels == category_id)
#   indices = np.argsort(features_chi2[0])
#   feature_names = np.array(tfidf.get_feature_names())[indices]
#   unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
#   bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
#   print("# '{}':".format(Product))
#   print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
#   print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))

# %%
# Naive Bayes Classifier: the one most suitable for word counts is the multinomial variant:

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(df['consumer_complaint_narrative'], df['product'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
# After fitting the training set, let’s make some predictions.

# %%
print(clf.predict(count_vect.transform(["This company refuses to provide me verification and validation of debt per my right under the FDCPA. I do not believe this debt is mine."])))
# Out:
# ['Debt collection']

# %%
df[df['consumer_complaint_narrative'] == "This company refuses to provide me verification and validation of debt per my right under the FDCPA. I do not believe this debt is mine."]
# Out:
# Empty DataFrame
# Columns: [product, consumer_complaint_narrative, category_id]
# Index: []

# %%
print(clf.predict(count_vect.transform(["I am disputing the inaccurate information the Chex-Systems has on my credit report. I initially submitted a police report on XXXX/XXXX/16 and Chex Systems only deleted the items that I mentioned in the letter and not all the items that were actually listed on the police report. In other words they wanted me to say word for word to them what items were fraudulent. The total disregard of the police report and what accounts that it states that are fraudulent. If they just had paid a little closer attention to the police report I would not been in this position now and they would n't have to research once again. I would like the reported information to be removed : XXXX XXXX XXXX"])))
# Out:
# ['Credit reporting']

# %%
df[df['consumer_complaint_narrative'] == "I am disputing the inaccurate information the Chex-Systems has on my credit report. I initially submitted a police report on XXXX/XXXX/16 and Chex Systems only deleted the items that I mentioned in the letter and not all the items that were actually listed on the police report. In other words they wanted me to say word for word to them what items were fraudulent. The total disregard of the police report and what accounts that it states that are fraudulent. If they just had paid a little closer attention to the police report I would not been in this position now and they would n't have to research once again. I would like the reported information to be removed : XXXX XXXX XXXX"]
# Out:
# Empty DataFrame
# Columns: [product, consumer_complaint_narrative, category_id]
# Index: []

# %% [markdown]
# ## Model Selection
# ### We are now ready to experiment with different machine learning models, evaluate their accuracy and find the source of any potential issues.
# ### We will benchmark the following four models:
# ### Logistic Regression
# ### (Multinomial) Naive Bayes
# ### Linear Support Vector Machine
# ### Random Forest

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score


models = [
#     RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
#     MultinomialNB(),
#     LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC    0.858457
# Name: accuracy, dtype: float64

# %% [markdown]
# # Model Evaluation
# # Continue with our best model (LinearSVC), we are going to look at the confusion matrix, and show the discrepancies between predicted and actual labels.

# %%
model = LinearSVC()
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.25, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df['product'].values, yticklabels=category_id_df['product'].values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# ### The vast majority of the predictions end up on the diagonal (predicted label = actual label), where we want them to be. However, there are a number of misclassifications, and it might be interesting to see what those are caused by:

# %%
from IPython.display import display
for predicted in category_id_df.category_id:
  for actual in category_id_df.category_id:
    if predicted != actual and conf_mat[actual, predicted] >= 10:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
      display(df.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['product', 'consumer_complaint_narrative']])
      print('')
# Out:
# 'Consumer Loan' predicted as 'Debt collection' : 122 examples.
#              product                       consumer_complaint_narrative
# 1687   Consumer Loan  I am being harassed by a company called http X...
# 66273  Consumer Loan  I have been contacted multiple times via Phone...
# 52131  Consumer Loan  account has been closed and no amount is due, ...
# 20743  Consumer Loan  Received un unsigned letter from Ford Credit i...
# 46173  Consumer Loan  I received a loan from world finance and and l...
# 14936  Consumer Loan  my car was repossedOn XXXX XXXX 2015 you recei...
# 49717  Consumer Loan  I was paying on a collections that was on my c...
# 59650  Consumer Loan  I have submitted a cease and desist letter to ...
# 34143  Consumer Loan  I currently have a debt to Springleaf Financia...
# 6751   Consumer Loan  I Requested this company in Writing to Validat...
#
# [122 rows x 2 columns]
# 'Mortgage' predicted as 'Debt collection' : 52 examples.
#         product                       consumer_complaint_narrative
# 27463  Mortgage  Upon trying to setup my account information af...
# 35670  Mortgage                           Civil Theft of a Note \n
# 8177   Mortgage  I received a phone call today from a man at ar...
# 46435  Mortgage  I filed bankruptcy ( case XXXX ) XXXX Californ...
# 41662  Mortgage  FAIR COLLECTIONS AND OUTSOURSING has placed er...
# 51005  Mortgage  The company in question ( DiTech, formally Gre...
# 60864  Mortgage  Attempted to file to CASE : XXXX and submit co...
# 25753  Mortgage  I owned a property that was foreclosed and I n...
# 25087  Mortgage  hardship loss job have not been able to recove...
# 35382  Mortgage  owed XXXX to B O A, house was sold thru short ...
# 62781  Mortgage  I found a foreclosure that never happened. I f...
# 56900  Mortgage  our mortgage was sold to a different company. ...
# 20821  Mortgage  We were trying to apply for a mortgage. Since ...
# 37262  Mortgage  Asked XXXX to defer XXXX payments, was told I ...
# 35596  Mortgage  My mortgage company NatuonStar has refused my ...
# 16518  Mortgage  Greentree has continued to attempt to collect ...
# 19846  Mortgage  I am a victim of identity theft. An identity t...
# 26464  Mortgage  I borrowed in 2005 from a private lender in XX...
# 44643  Mortgage  account is in bk and they reported everything ...
# 37836  Mortgage  I ordered my credit reports from all XXXX agen...
# 43904  Mortgage  My house foreclosed and I had a second mortgag...
# 40720  Mortgage  My bankruptcy was discharged a few years ago a...
# 47661  Mortgage  I filed a complaint with your agency with a re...
# 41734  Mortgage  A credit report was requested and Real Time Re...
# 31149  Mortgage  Fraud by US Bank NA ( USB ). USB claims to be ...
# 13079  Mortgage  A recent check on the XXXX XXXX XXXX XXXX XXXX...
# 63946  Mortgage  I had originally filed a complaint in XXXX of ...
# 18235  Mortgage  Ongoing collections calls for an XXXX XXXX who...
# 29077  Mortgage  I entered a Discount Settlement agreement and ...
# 57169  Mortgage  On XXXX XXXX, 2016 I appeared at an alleged cr...
# 23045  Mortgage  I currently own my home at XXXX XXXX XXXX XXXX...
# 43773  Mortgage  BANK OF AMERICA THE Alleged Investor /Owner of...
# 5437   Mortgage  I am beginning to receive calls at my current ...
# 34459  Mortgage  ( 1 ) The quick and dirty is my house was fore...
# 37053  Mortgage  Case number : XXXX they forced a agreement and...
# 38211  Mortgage  XXXX XXXXAccount XXXXChaseXXXX XXXX Ohio XXXXJ...
# 33180  Mortgage  A letter was sent via certified mail to Frankl...
# 11155  Mortgage  I applied for a reverse mrtg with XXXX and was...
# 16942  Mortgage  This is additional information for case # XXXX...
# 43644  Mortgage  After going through repeated phone calls and a...
# 14248  Mortgage  I can not get anyone in the company to respond...
# 11284  Mortgage  I have periodically received solicitations fro...
# 19734  Mortgage  I have a home equity loan with the Pentagon Fe...
# 60593  Mortgage  First to take action on a foreclosure, fraud n...
# 50511  Mortgage  Please refer to the attached Cease and Desist ...
# 49217  Mortgage  The United States Bankruptcy Court in XXXX XXX...
# 62454  Mortgage  I represent XXXX and XXXX XXXX who own a home ...
# 48838  Mortgage  I have researched my records and I am showing ...
# 40912  Mortgage  Hello, my name is XXXX XXXX and i already send...
# 13240  Mortgage  We are in a hardship and received a letter reg...
# 37432  Mortgage  In this case discovery was never completed, co...
# 3501   Mortgage  I changed accounts from which my driect debt w...
# 'Credit card' predicted as 'Debt collection' : 124 examples.
#            product                       consumer_complaint_narrative
# 4800   Credit card  For a medical service my wife made an advance ...
# 53120  Credit card  NETCREDIT made false statements to cfpb. I sus...
# 56712  Credit card  TJmaxx Reward/Synchrony. and or their collecti...
# 46585  Credit card  we have learned the debt collector, XXXX XXXX,...
# 31283  Credit card  On XXXX/XXXX/15 I received a phone message fro...
# 38732  Credit card  A man named XXXX XXXX called my new husband tr...
# 1610   Credit card  The company denied my dispute of XXXX XXXX cha...
# 4780   Credit card  We had fraud in our office and money was stole...
# 42285  Credit card  I contacted XXXX about a couple months ago and...
# 52700  Credit card  I wish to have your assistance in disputing XX...
# 14875  Credit card  XXXX XXXX XXXX XXXX NY XXXXXXXXXXXX XXXX XXXX ...
# 31759  Credit card  I filed for bankruptcy in XX/XX/XXXX and was g...
# 21219  Credit card  Portfolio Recovery Associates has tried twice ...
# 59939  Credit card  Never received bill. First and only purchase i...
# 52784  Credit card  Capital One has intimidated and harasses me an...
# 53451  Credit card  I am being contacted by XXXX XXXX XXXX about a...
# 65463  Credit card  I recently pulled my XXXX and XXXX ctedit repo...
# 38138  Credit card  There is an item on my Credit Bureau reports t...
# 48818  Credit card  Bank of America has an old debt of mine that t...
# 24819  Credit card  XXXX XXXX XXXX of the company, XXXX XXXX XXXX ...
# 9758   Credit card  Wrong information on credit report. Company is...
# 27468  Credit card  Have continuously asked agency to stop calling...
# 31963  Credit card  my account is closed and its been years and IR...
# 6228   Credit card  I was contacted by a collection agency about a...
# 56463  Credit card  Citibank card ( XXXX ) has been calling both m...
# 27812  Credit card  i had a credit card with XXXX from when i was ...
# 3437   Credit card  The original creditor, Wells Fargo Bank, sold ...
# 8519   Credit card  I keep receiving phone calls from a debt colle...
# 63584  Credit card  Constant calls concerning credit account which...
# 56233  Credit card  This complaint is regarding SYNCHRONY FINANCIA...
# ...            ...                                                ...
# 6296   Credit card  Bank of America emailed me an eroneous bill. T...
# 27760  Credit card  We have had repeated robocalls from Synchrony ...
# 4180   Credit card  Late with payments, made payment plan arrangem...
# 44483  Credit card  Portfolio Recovery Corp ( PRC ) continues to c...
# 33092  Credit card  Credit card capital one has been notified by n...
# 46801  Credit card  I got the information from credit report and w...
# 49830  Credit card  Each year the XXXX and the law firm who is rep...
# 28666  Credit card  I have frequently received letters from a comp...
# 59938  Credit card  I owed {$29.00} to J.C. Penney ; due XXXX XXXX...
# 15294  Credit card  Chase Account # XXXX. Owed XXXX-made arrangeme...
# 8011   Credit card  I did not know the category to select, but thi...
# 42895  Credit card  Portfolio Recovery services collected a debt t...
# 55878  Credit card  I started to receive calls from XXXX. I called...
# 40569  Credit card  I received a call from a company that would n'...
# 45087  Credit card  I have received phone calls from Midland Credi...
# 45845  Credit card  I arranged for a payment plan to make good on ...
# 16379  Credit card  I settled an old credit card in 2001. This wee...
# 8602   Credit card  I was contacted by kirkland Management in New ...
# 51230  Credit card  A summons with someone of a similar name as mi...
# 61244  Credit card  Misrepresented time to repay the loan and when...
# 29076  Credit card  Years ago I used my Bank of America card to ke...
# 4022   Credit card  I purchased a pair of eyeglasses fro XXXX XXXX...
# 30152  Credit card  The bank did not validate this debt based on t...
# 10162  Credit card  i rented a car with my credit card which has r...
# 53481  Credit card  Was charged {$590.00} on XXXX XXXX, 2015 for n...
# 16203  Credit card  I am working with a debt company who has legal...
# 30753  Credit card  I am on the DO NOT CALL REGISTRY and get calls...
# 22518  Credit card  On XXXX XXXX I call XXXX XXXX XXXX and gave my...
# 27836  Credit card  I had a credit card debt of XXXX. I went throu...
# 46623  Credit card  XXXX XXXX of Continental Finance did knowing k...
#
# [124 rows x 2 columns]
# 'Credit reporting' predicted as 'Debt collection' : 211 examples.
#                 product                       consumer_complaint_narrative
# 15366  Credit reporting  Any and all medical bills reported by any agen...
# 3603   Credit reporting  I have informed XXXX XXXX many time that XXXX ...
# 8142   Credit reporting  the XXXX bureaus have falsified my credit rati...
# 16790  Credit reporting  We moved in XXXX of 2014 to XXXX from XXXX. XX...
# 17753  Credit reporting  At the time of this visit to the hospital I wa...
# 30113  Credit reporting  I checked my credit report and noticed that th...
# 20451  Credit reporting  XXXX {$320.00} was paid and clearedConfirmatio...
# 21349  Credit reporting  The creditors have wrong personal information....
# 17038  Credit reporting  I have paid off the debt to Procollect on XXXX...
# 25890  Credit reporting  XXXX XXXX is a collection agency attempting to...
# 66710  Credit reporting  The debt is not mine because I am and was not ...
# 18318  Credit reporting  Heating service claimed they checked my furnac...
# 11448  Credit reporting  XXXX 2010 i rented an apartment for six months...
# 36572  Credit reporting  My husband and I have auto insurance coverage ...
# 56017  Credit reporting  I HAVE FILED 3 TIMES TO THEM THAT I HAVE NOT A...
# 8619   Credit reporting  a manager of an apartment complex was trying t...
# 61938  Credit reporting  My account is related to an old case number : ...
# 36247  Credit reporting  I tried to dispute it with DIVERSIFIED CONSULT...
# 64685  Credit reporting  XXXX Bank pursued me for a {$140.00} charge th...
# 32790  Credit reporting  i paid XXXX long time ago and the collection i...
# 41535  Credit reporting  I have been reviewing my credit report closely...
# 7508   Credit reporting  The above is what was issued for the report-ca...
# 63519  Credit reporting  Am a victim of identity theft which took place...
# 45614  Credit reporting  the date is wrong when the collection was put ...
# 41014  Credit reporting  Signed up with a billing company to pay for a ...
# 12207  Credit reporting  XXXX XXXX Bank XXXX XXXX As per the Florida st...
# 26840  Credit reporting  They took off the collection account because t...
# 15811  Credit reporting  This company is reporting false negative infor...
# 35544  Credit reporting  my name is XXXX XXXX i live at XXXX XXXX XXXX ...
# 30157  Credit reporting  It is being reported that I owe XXXX money and...
# ...                 ...                                                ...
# 27149  Credit reporting  Have a DR using my name also a address in XXXX...
# 44905  Credit reporting  I need to get a secure alert apparently somebo...
# 56067  Credit reporting  A company called XXXX is showing up in my cred...
# 49031  Credit reporting  I rented an apartment to XXXX XXXX managed by ...
# 31906  Credit reporting  Dispute Over Inquiries on XXXX Credit Report- ...
# 26354  Credit reporting  Derogative credit report but I never received ...
# 22421  Credit reporting  I had my son in a daycare called the XXXX XXXX...
# 55427  Credit reporting  NCS agreed to remove a debt listed on my credi...
# 29766  Credit reporting  I have a {$3400.00} debt listed on my credit r...
# 12673  Credit reporting  Sent creditor copy of discharge notice but hav...
# 19615  Credit reporting  To whom it may concern, I was XXXX in 2010 fro...
# 63828  Credit reporting  I want to have this issue removed from XXXX an...
# 7921   Credit reporting  We took our XXXX for an emergency but we had t...
# 64262  Credit reporting  This compalint is about XXXX services. I disco...
# 40972  Credit reporting  There is an account that displays incorrect in...
# 867    Credit reporting  I had a dispute with XXXX over some overcharge...
# 14647  Credit reporting  I have spoken to XXXX and reinstated my accoun...
# 36399  Credit reporting  I am disputing the charge from, XXXX Business,...
# 25497  Credit reporting  I have a company called XXXX XXXX XXXX XXXX th...
# 40999  Credit reporting  XX/XX/2012 I was taken against my will and aut...
# 18490  Credit reporting  original debt owed to XXXX XXXX visa. \nover 7...
# 8574   Credit reporting  Bill paid by insurance please remove this from...
# 61728  Credit reporting  The debt collector agreed to have items remove...
# 23882  Credit reporting  My XXXX student loans defaulted and I have bee...
# 53819  Credit reporting  XXXX XXXX XXXX ( XXXX ) XXXX XXXX XXXX XXXX XX...
# 17426  Credit reporting  I talked with this company directly about 2-3y...
# 34436  Credit reporting  At the time of the lease agreement, I was unde...
# 40257  Credit reporting  NOT A DEEP INVESTIGATION. THE NEGATIVES ARE NO...
# 60882  Credit reporting  I have a XXXX XXXX XXXX XXXX dispute on credit...
# 50902  Credit reporting  credit history has hit because of wrong attemp...
#
# [211 rows x 2 columns]
# 'Student loan' predicted as 'Debt collection' : 48 examples.
#             product                       consumer_complaint_narrative
# 58434  Student loan  COLLECTION NOTICE SENT TO MY DECEASED MOTHER I...
# 30855  Student loan  Questionable debt collecting agency XXXX Sunri...
# 12226  Student loan  Pioneer credit recovery has been harassing me ...
# 17802  Student loan  AES/NCT/XXXX have multiple credit marks on my ...
# 6366   Student loan  I was contacted by American Education Services...
# 63871  Student loan  Due to unemployment was unable to continue wit...
# 29846  Student loan         Trumped up my principal owed illegally. \n
# 41798  Student loan  I borrowed from XXXX towards my XXXX education...
# 62501  Student loan  Co-signer of loan not notified of non payment ...
# 20440  Student loan  I am not sure if my loan is federal or private...
# 16598  Student loan  In XXXX 2014, I filed a complaint against XXXX...
# 22658  Student loan  Student loan with Wells Fargo constantly calli...
# 24684  Student loan  XXXX has repeatedly failed to process informat...
# 46584  Student loan  Was working on my XXXX at XXXX University and ...
# 39416  Student loan  I had a student loan in XXXX back in the XXXX ...
# 53858  Student loan  My loan was sold to a private collections comp...
# 54610  Student loan  *****This is my 7th complaint over this fraudu...
# 18551  Student loan  Allied Interstae has received my debt from XXX...
# 18761  Student loan  I took out a student loan for my son, XXXX XXX...
# 22712  Student loan  Navient has refused to work with my repayment,...
# 5717   Student loan  The amount demanded far exceed what I can pay ...
# 53597  Student loan  I set up a payment plan with LTD Financial Ser...
# 25658  Student loan  Firstmark Services, a division of Nelnet, has ...
# 1218   Student loan  Initial letters from Sunrise Credit Services (...
# 63125  Student loan  I have been battling with this company for mon...
# 66     Student loan  I was behind on my loans, and I called about t...
# 38206  Student loan  There is a third party debt collection company...
# 19452  Student loan  My wife attended a XXXX and still has some deb...
# 22679  Student loan  I paid off a XXXX XXXX student loan in 2008. I...
# 38129  Student loan  I found many inconsistencies in the alleged am...
# 31499  Student loan  I request for my Credit report be sent to me a...
# 728    Student loan  I have recently had a wage garnishment put in ...
# 65202  Student loan  Have been harassed and bombarded with numerous...
# 45259  Student loan  I was XXXX when I had a meeting about how to p...
# 52477  Student loan  XX/XX/XXXX I was supposed to be put into a pro...
# 25857  Student loan  CONSTANT harassment from Navient regarding a s...
# 2419   Student loan  Company is Asset Recovery Solutions , LLC. Con...
# 26966  Student loan  I had a student loan in 2007. I was unable to ...
# 17987  Student loan  I have defaulted on a student loan from nation...
# 3014   Student loan  XXXX XXXX, XXXX XXXX, and University XXXX XXXX...
# 17418  Student loan  Navient has violated the Fair Credit and Repor...
# 23385  Student loan  They refused to provide me with a payment ledg...
# 13024  Student loan  daughter received loans from wells fargo, daug...
# 47055  Student loan  On XXXX XXXX, 2015, I was informed by the CFPB...
# 6274   Student loan  People from a phone number XXXX XXXX XXXX XXXX...
# 2787   Student loan  Navient XXXX XXXX XXXX XXXX has been calling m...
# 28221  Student loan  I have already filed XXXX complaint case # XXX...
# 36643  Student loan  My XXXX assist loans are in default after XXXX...
# 'Bank account or service' predicted as 'Debt collection' : 30 examples.
#                        product  \
# 42907  Bank account or service
# 31056  Bank account or service
# 9961   Bank account or service
# 40734  Bank account or service
# 2287   Bank account or service
# 30183  Bank account or service
# 11746  Bank account or service
# 8309   Bank account or service
# 41173  Bank account or service
# 61458  Bank account or service
# 33881  Bank account or service
# 29996  Bank account or service
# 51712  Bank account or service
# 48370  Bank account or service
# 47951  Bank account or service
# 32594  Bank account or service
# 22117  Bank account or service
# 55259  Bank account or service
# 58873  Bank account or service
# 6740   Bank account or service
# 822    Bank account or service
# 48891  Bank account or service
# 32068  Bank account or service
# 41883  Bank account or service
# 40449  Bank account or service
# 60140  Bank account or service
# 19575  Bank account or service
# 49244  Bank account or service
# 8805   Bank account or service
# 51786  Bank account or service
#
#                             consumer_complaint_narrative
# 42907  Santander bank is constantly calling and leavi...
# 31056  A CHECK WAS WRITTEN OFF MY ACCOUNT AND HONORED...
# 9961   My elderly parents were sold a trust from Well...
# 40734  Bank of America has been trying to collect on ...
# 2287   I had an account for an IRA with a company. Th...
# 30183  Hi my Name is XXXX XXXX I received a call from...
# 11746  " Google XXXX XXXX '' calls XXXX or XXXX times...
# 8309   We finance a bed bought at XXXX in XXXX 2014. ...
# 41173  There is an account with Pioneer/XXXX XXXX XXX...
# 61458  Citibank decided on their own not to send me m...
# 33881  The US bank continues harassing me with teleph...
# 12056  Mortgage  Case # XXXX THIS IS NOT A DUPLICATE ... The Co...
# 'Credit card' predicted as 'Consumer Loan' : 10 examples.
#            product                       consumer_complaint_narrative
# 30790  Credit card  Capital One has reported 30 days late on my cr...
# 4951   Credit card  I had a credit card with Banco Santander XXXX ...
# 1761   Credit card  In 2005, we took out what we thought was a loa...
# 28563  Credit card  I 'm not sure if this is the most appropriate ...
# 10826  Credit card  XXXX XXXX, XXXX, my husband and I entered into...
# 59267  Credit card  Lobel Financial is in clear violation of the F...
# 28533  Credit card  Listing closed account as open, last payment X...
# 60242  Credit card  I paid to get a XXXX put in my truck on XXXX X...
# 60468  Credit card  I purchased a TV from XXXX. Placed payments ( ...
# 27060  Credit card  On XXXX XXXX, 2015 I submitted a payment reque...
# 'Credit reporting' predicted as 'Consumer Loan' : 26 examples.
#                 product                       consumer_complaint_narrative
# 21141  Credit reporting  THERE WAS INQUIRES ON MY CREDIT REPORT THAT I ...
# 52301  Credit reporting  Our car was totalled after we were hit by anot...
# 55417  Credit reporting  I purchased a a car from XXXX XXXX. in XXXX. I...
# 14894  Credit reporting  I traded in 2013 XXXX XXXX that was financed w...
# 39867  Credit reporting  I have contacted Capital One Auto Finance, sev...
# 1648   Credit reporting  An car loan that supposedly was taken out on X...
# 66252  Credit reporting  On XXXX/XXXX/XXXX I went into XXXX XXXX of XXX...
# 14684  Credit reporting  My issue is with a car lease. The car was not ...
# 6838   Credit reporting  My complaint involves XXXX XXXX XXXX in XXXX. ...
# 789    Credit reporting  In XXXX I purchased a vehicle and became ill r...
# 45380  Credit reporting  This complaint is regarding claim ( # XXXX ) I...
# 7482   Credit reporting  I had voluntarily returned a vehicle to XXXX X...
# 48890  Credit reporting  XXXX pulled my credit report without my consen...
# 38240  Credit reporting  The Car Loan for XXXX Lincoln Navigator with X...
# 11552  Credit reporting  I have recieved over XXXX hit on my credit try...
# 6250   Credit reporting  I have an account with XXXX I opened an accoun...
# 27214  Credit reporting  I HAVE RECIVED LETTERS IN THE MAIL REGARDING A...
# 42565  Credit reporting  On XX/XX/2015, I received financing for the pu...
# 47072  Credit reporting  a company called XXXX XXXX XXXX made a hard in...
# 19845  Credit reporting  Credit report has been shared with car loan co...
# 50901  Credit reporting  Dear Sir or Madam : We are writing to dispute ...
# 41603  Credit reporting  There is an apparent personal loan on my repor...
# 38250  Credit reporting  I traded in my vehicle on XXXX/XXXX/2015 and j...
# 18980  Credit reporting  My loan from XXXX for {$36000.00} is no longer...
# 9878   Credit reporting  Florida XXXX XXXX account # XXXX I paid all of...
# 15694  Credit reporting  we have paid off the XXXX ford truck I want it...
# 'Payday loan' predicted as 'Consumer Loan' : 15 examples.
#            product                       consumer_complaint_narrative
# 33510  Payday loan  I am writing this as a customer who feels as t...
# 32820  Payday loan  Advance America Cash Advance ; XXXX XXXX XXXX ...
# 61976  Payday loan  Upon change from one job to another, I promptl...
# 42781  Payday loan  I unable to repay Ace cash express and the loa...
# 61556  Payday loan  I received an installment loan of {$500.00} on...
# 25545  Payday loan  XXXX XXXX # XXXXAdvance Financial XXXX XXXX XX...
# 58123  Credit card  Wells Fargo ( Platinum Visa ) has recently ins...
# 62779  Credit card  On XXXX XXXX, 2016 I redeemed XXXX Everyday Re...
# 615    Credit card  I HAD A CREDIT BALANCE ON MY ACCOUNT OF XXXX C...
# 60317  Credit card  I have XXXX ( XXXX ) credit cards from Capital...
# 16792  Credit card  In a attempt to clean up my debit with discove...
# 50644  Credit card  Bank of America claims I am past due when I am...
# 65815  Credit card  I lost my job last XXXX so I was unable to mak...
# 49207  Credit card  I had a secured credit card with Wells Fargo. ...
# 18410  Credit card  Last month on XXXX XXXX I made a payment to my...
# 49820  Credit card  We paid off our Citi Bank XXXX in XXXX XXXX an...
# 61511  Credit card  I am an Arizona-based XXXX XXXX XXXX that prov...
# 62540  Credit card  Regions Bank is reporting a fraudulent credit ...
# 36709  Credit card  This issue is related to Kohl 's Department St...
# 47464  Credit card  PayPal misled customers into signing up for li...
# 35998  Credit card  On XXXX/XXXX/2015 I opened a BofA checking acc...
# 5841   Credit card  I RECEIVED A PROMOTIONAL OFFER FROM CENTER STA...
#
# [61 rows x 2 columns]
# 'Money transfers' predicted as 'Bank account or service' : 30 examples.
#                product                       consumer_complaint_narrative
# 33702  Money transfers  Requested subpoenaed records from Bank of Amer...
# 30351  Money transfers  I transferred XXXX USD through JPM CHASE on XX...
# 4461   Money transfers  I made a wire transfer through Citibank to XXX...
# 58953  Money transfers  I have got scamed this person called me on the...
# 49958  Money transfers  As an ebay XXXX, I have been dealing with rece...
# 14158  Money transfers  On XX/XX/XXXX I responded to a XXXX vacation r...
# 6082   Money transfers  Paypal submitted a credit check on myself, wit...
# 37272  Money transfers  On XXXX, XXXX, and finally on XXXX I attempted...
# 40553  Money transfers  On XXXX XXXX, 2015, I received an email from a...
# 43794  Money transfers  HSBC Bank N.A Is always confiscating money tra...
# 1971   Money transfers  On EBAY, I had to take down all my items. I 'm...
# 64168  Money transfers  We recently asked our Wells Fargo branch in XX...
# 19035  Money transfers  I went to see an apt that i wanted to rent fro...
# 47771  Money transfers  I have a Bank Account, and a Credit Card, regi...
# 17536  Money transfers  In the past 10 years I have requested wire tra...
# 31170  Money transfers  I am purchasing a house and my mother and my s...
# 55755  Money transfers  My wife ( XXXX XXXX ) and I were having e-mail...
# 1480   Money transfers  I recently opened an account with PayPal. I pu...
# 51468  Money transfers  On XXXX/XXXX/15 I went to the XXXX XXXX XXXX a...
# 63244  Money transfers  i sent money threw XXXX XXXX XXXX the receiver...
# 27619  Money transfers  After being a loyal user with Paypal for 7 yea...
# 46502  Money transfers  Transfer was pending at recipient bank for ove...
# 57663  Money transfers  Paypal is arbitrarily applying hold policies d...
# 35985  Money transfers  I requested PayPal to send me a check of {$500...
# 13618  Money transfers  Hello, I am a victim of a fraud for false vaca...
# 56513  Money transfers  I would like to close my Paypal account, " XXX...
# 4573   Money transfers  I was scammed by another Bank of America clien...
# 39243  Money transfers  I 've had a Google Waller account for some tim...
# 48561  Money transfers  I have my mother 's financial power of attorne...
# 11031  Money transfers  On XXXX XXXX, 2014 Paypal " limited '' XXXX of...
# 'Bank account or service' predicted as 'Money transfers' : 16 examples.
#                        product  \
# 66757  Bank account or service
# 1963   Bank account or service
# 34432  Bank account or service
# 22550  Bank account or service
# 4226   Bank account or service
# 18296  Bank account or service
# 14061  Bank account or service
# 50009  Bank account or service
# 66758  Bank account or service
# 33806  Bank account or service
# 11476  Bank account or service
# 7032   Bank account or service
# 22414  Bank account or service
# 6936   Bank account or service
# 15865  Bank account or service
# 19030  Bank account or service
#
#                             consumer_complaint_narrative
# 66757  On XXXX XXXX, 2016, I initiated a " Send Money...
# 1963   Bank is unable to retrieve transfer that was d...
# 34432  ! I was scammed out of {$8900.00} of my hard e...
# 22550  I was trying to send remittance ( amount of {$...
# 4226   I did accept a transfer service that was offer...
# 18296  Because of a lawsuit that my partner and I hav...
# 14061                     recd text from XXXXXXXXXXXX \n
# 50009  I had to transfer money into my US Bank Accoun...
# 66758  I paid via Paypal a friend for a game currency...
# 33806  Dear sir or madam, This is regarding my XXXX P...
# 11476  I wired money on XXXX/XXXX/2015 from USAA acco...
# 7032   I was charged an overdraft fee in the amount o...
# 22414  I had been making online purchases with my Pay...
# 6936   I have a PayPal account, which I will never us...
# 15865  I sent a western union ebill ( WU Pay ) for th...
# 19030  A wire transfer was issued from XXXX XXXX XXXX...
# 'Bank account or service' predicted as 'Prepaid card' : 45 examples.
#                        product  \
# 57377  Bank account or service
# 64516  Bank account or service
# 40875  Bank account or service
# 56489  Bank account or service
# 57286  Bank account or service
# 59132  Bank account or service
# 57130  Bank account or service
# 58076  Bank account or service
# 56628  Bank account or service
# 41874  Bank account or service
# 58056  Bank account or service
# 23414  Bank account or service
# 53902  Bank account or service
# 28702  Bank account or service
# 57456  Bank account or service
# 89     Bank account or service
# 56876  Bank account or service
# 17552  Bank account or service
# 57384  Bank account or service
# 58710  Bank account or service
# 59560  Bank account or service
# 55823  Bank account or service
# 37486  Bank account or service
# 57275  Bank account or service
# 16802  Bank account or service
# 35129  Bank account or service
# 58299  Bank account or service
# 60097  Bank account or service
# 58415  Bank account or service
# 57550  Bank account or service
# 54223  Bank account or service
# 31580  Bank account or service
# 61979  Bank account or service
# 22332  Bank account or service
# 5807   Bank account or service
# 7886   Bank account or service
# 59449  Bank account or service
# 14886  Bank account or service
# 162    Bank account or service
# 57958  Bank account or service
# 64584  Bank account or service
# 29493  Bank account or service
# 10164  Bank account or service
# 19951  Bank account or service
# 62601  Bank account or service
#
#                             consumer_complaint_narrative
# 57377  XXXX XXXX co founder of Rush card has been sec...
# 64516  Today, XXXX/XXXX/16, I received a XXXX XXXX ca...
# 40875  This is the second time my card with comerca b...
# 56489  on XXXX XXXX XXXX I called rushcard to say my ...
# 57286  On XXXX/XXXX/2015, Rushcard scheduled system m...
# 59132  Rush card has completely been so disrespectful...
# 57130  Rush Card did routine maintenance to a new ser...
# 58076  On XXXX XXXX 2015 I cash a check with the comp...
# 56628  I have a Rushcard and my pay is deposited twic...
# 41874  I keep getting junk mail from NetSpend. They w...
# 58056  rush card, stated that there was computer main...
# 23414  ILLEGAL & CAPRICIOUS SEIZURE AND HOLDING OF CO...
# 53902  XXXX charged my account {$12.00} even after I ...
# 28702  Paypal wo n't let me withdraw my money. The op...
# 57456  Do to rushcard my bills are being late and im ...
# 89     I receive government VA XXXX benefits that are...
# 56876  I have n't received my direct deposit which go...
# 17552  I have XXXX proplems XXXX with XXXX and the pr...
# 57384  My name is XXXX XXXX and my employer posted ou...
# 58710  I 've been with Rush Card 8 years and they hav...
# 59560  XXXX : The following is the over view of my is...
# 55823  I have a dispute with Direct Express Dispute D...
# 37486  It was about XXXX prepaid debit card .I was so...
# 57275  I am having an issue with Rush Card debit ever...
# 16802  XXXX of my prepaid debit visa gift card issued...
# 35129  I bought a prepaid XXXX card from XXXX. The ca...
# 58299  I bank with Rushcard! I have yet to receive my...
# 60097  Rush card has not released my direct deposit. ...
# 58415  Well first off i have a rushcard. I understand...
# 57550  Rush card did an update on their system and so...
# 54223  From XXXX XXXX, XXXX to XXXX XXXX, XXXX I was ...
# 31580  On XXXX XXXX, 2015, PayPal limited my account ...
# 61979  My accounts were closed abruptly and I was una...
# 22332  I purchased a {$500.00} reload pack from XXXX ...
# 5807   Received unsolicited Visa debit card from netS...
# 7886   My prepaid debit account managed by Blackhawk ...
# 59449  My employer direct deposited my payroll check ...
# 14886  I have a debit card from XXXX expiring in XXXX...
# 162    I filed my income taxes to turbo tax .I was su...
# 57958  I have been a member with Rushcard for about t...
# 64584  I use Rushcard services for my military XXXX d...
# 29493  Social Security deposited funds into US Direct...
# 10164  The key issue here is that netspend debit card...
# 19951  Well I have had problems with accessing my acc...
# 62601  My story is pretty simple. I work for the stat...

# %% [markdown]
# ### Again, we use the chi-squared test to find the terms that are the most correlated with each of the categories:

# %%
# model.fit(features, labels)
# N = 2
# for Product, category_id in sorted(category_to_id.items()):
#   indices = np.argsort(model.coef_[category_id])
#   feature_names = np.array(tfidf.get_feature_names())[indices]
#   unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
#   bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
#   print("# '{}':".format(Product))
#   print("  . Top unigrams:\n       . {}".format('\n       . '.join(unigrams)))
#   print("  . Top bigrams:\n       . {}".format('\n       . '.join(bigrams)))

# %% [markdown]
# # Finally, we print out the classification report for each class:

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred, target_names=df['product'].unique()))
# Out:
#                          precision    recall  f1-score   support
#
#         Debt collection       0.86      0.90      0.88      4385
#           Consumer Loan       0.82      0.66      0.73       954
#                Mortgage       0.93      0.96      0.95      3756
#             Credit card       0.83      0.84      0.84      2003
#        Credit reporting       0.87      0.89      0.88      3010
#            Student loan       0.95      0.85      0.90       546
# Bank account or service       0.85      0.80      0.83      1490
#             Payday loan       0.63      0.35      0.45       161
#         Money transfers       0.77      0.61      0.68       171
# Other financial service       1.00      0.10      0.17        21
#            Prepaid card       0.74      0.76      0.75       205
#
#                accuracy                           0.87     16702
#               macro avg       0.84      0.70      0.73     16702
#            weighted avg       0.87      0.87      0.87     16702
